# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Import local modules

# %%
import sys
sys.path.insert(0, '../src')

import os

from utils.exp_saver import ExpSaver
from utils.utils import format_results

from data_loading.load_cas import load_cas
from data_loading.load_embeddings import load_vectors
from data_loading.load_neg_filters import load_filters

from data_processing.preprocessing import preprocess_data, add_tags_per_word
# Out:
# Using TensorFlow backend.
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Import universal modules

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

import numpy as np
import glob

from gensim.models.fasttext import load_facebook_model, load_facebook_vectors

# %% [markdown]
# # Parameters (edit in notebooks/params.yml)

# %%
import ruamel.yaml
with open('params.yml') as f:
    params = ruamel.yaml.load(f)
    
print(params)

if params['model_structure']['lib'] in ['torch', 'pytorch']:
    from train.train_torch import CV_train
else:
    from train.train import CV_train
# Out:
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UnsafeLoaderWarning:
# The default 'Loader' for 'load(stream)' without further arguments can be unsafe.
# Use 'load(stream, Loader=ruamel.yaml.Loader)' explicitly if that is OK.
# Alternatively include the following in your code:
#
#   import warnings
#   warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# In most other cases you should consider using 'safe_load(stream)'
#   This is separate from the ipykernel package so we can avoid doing imports until
# {'pretrainedEmbed': 'fasttext', 'label_level': 'sentence', 'neg_only': False, 'n_fold': 10, 'batch_size': 32, 'epochs': 100, 'hyper_params': {'lr': 0.001, 'lr_decay': 0, 'dropout': 0.3}, 'model_structure': {'with_attention': True, 'lib': 'torch', 'with_crf': False, 'word_embed': 300, 'pos_embed': None, 'cue_embed': None, 'lstm_size': 300}}

# %% [markdown]
# # Block to rename folders in case of new parameter

# %%
# logs_folder = '../logs/*'

# from glob import glob
# import os

# for directory in glob(logs_folder):
#     if os.path.isdir(directory):
#         dir_path, dir_name = directory.rsplit('/', 1)
#         insert_index = dir_name.index('neg_only')
#         new_dir_name = dir_name[:insert_index] + 'label_level+word___' + dir_name[insert_index:]
#         os.rename(directory, dir_path + '/' + new_dir_name)

# %% [markdown]
# # Load corpus

# %%
cas = load_cas()

from ipywidgets import IntProgress

# get ids of sentences containing negation
negative_sentence_ids = cas.groupby('sentence_id').apply(lambda x : x['label'].str.contains('neg')).dropna().index.get_level_values(0).unique()

classes = ['O_neg', 'B_neg', 'I_neg']
# Out:
#   1%|          | 426/75258 [00:00<00:17, 4253.87it/s]
# Grouping negation
# 100%|██████████| 75258/75258 [00:47<00:00, 1583.66it/s]

# %% [markdown]
# # Retain only neg or not

# %%
neg_only = load_filters() if params['neg_only']=='filter' else params['neg_only']

if isinstance(neg_only, str):
    df1 = add_tags_per_word(cas, neg_only)  
    merge = cas.reset_index().merge(df1, left_index=True, right_index=True)
    neg_sentences = merge[merge['label_y'].str.contains('B_neg|I_neg')]['sentence_id_x'].unique()
    cas_neg = cas[cas['sentence_id'].isin(neg_sentences)]
elif neg_only==True:
    cas_neg = cas.groupby('sentence_id').filter(lambda x: (x['label'].str.contains('B').any()) or (x['label'].str.contains('I').any()))
else:
    cas_neg = cas.copy()
        
if neg_only:
    reset_sentence_dic = {w: i for i,w in enumerate(cas_neg['sentence_id'].unique())}
    cas_neg['sentence_id'] = cas_neg['sentence_id'].map(reset_sentence_dic).astype(int)

# %% [markdown]
# # Check filter accuracy, sentence wise

# %%
if not isinstance(neg_only, bool):
    from sklearn.metrics import classification_report

    true_neg = []
    pred_neg = []

    for sentence_id, sentence in cas.groupby('sentence_id'):

        true_labels = sentence['label'].unique()

        true_neg.append(('B_scope_neg' in true_labels) or ('I_scope_neg' in true_labels))

        pred_neg.append(sentence_id in neg_sentences)

        if (sentence_id in neg_sentences) and not (('B_scope_neg' in true_labels) or ('I_scope_neg' in true_labels)):
            display(sentence)


    print("Predicted support: \nO_neg: %d\nI_neg: %d"%(len(pred_neg)-sum(pred_neg), sum(pred_neg)))
    print(classification_report(true_neg, pred_neg, target_names=['O_neg', 'I_neg']))

# %%
# WITHOUT PUNCTUATION (with punctuation, results crumble)

# Predicted support: 
# O_neg: 2888
# I_neg: 902
#               precision    recall  f1-score   support

#        O_neg       0.99      0.96      0.98      2984
#        I_neg       0.87      0.97      0.92       806

#     accuracy                           0.96      3790
#    macro avg       0.93      0.97      0.95      3790
# weighted avg       0.97      0.96      0.96      3790

# %% [markdown]
# # Sample one random negative sentence to check

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

random_neg_sentence = np.random.choice(negative_sentence_ids)
display(cas[cas['sentence_id']==random_neg_sentence])

pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',None)
# Out:
#        sentence_id  word_id          word          lem    postag    cue_tag  \
# 22676         1020        0            L'           le   DET:ART          _
# 22677         1020        1          état         état       NOM          _
# 22678         1020        2            de           de       PRP          _
# 22679         1020        3            la           le   DET:ART          _
# 22680         1020        4        malade       malade       NOM          _
# 22681         1020        5            ne           ne       ADV  B_cue_neg
# 22682         1020        6    permettait    permettre  VER:impf          _
# 22683         1020        7           pas          pas       ADV  I_cue_neg
# 22684         1020        8            de           de       PRP          _
# 22685         1020        9     confirmer    confirmer  VER:infi          _
# 22686         1020       10            le           le   DET:ART          _
# 22687         1020       11    diagnostic   diagnostic       NOM          _
# 22688         1020       12           par          par       PRP          _
# 22689         1020       13            d'           de   DET:ART          _
# 22690         1020       14        autres        autre       ADJ          _
# 22691         1020       15  explorations  exploration       NOM          _
#
#              label
# 22676            _
# 22677            _
# 22678            _
# 22679            _
# 22680            _
# 22681  B_scope_neg
# 22682  I_scope_neg
# 22683  I_scope_neg
# 22684  I_scope_neg
# 22685  I_scope_neg
# 22686  I_scope_neg
# 22687  I_scope_neg
# 22688  I_scope_neg
# 22689  I_scope_neg
# 22690  I_scope_neg
# 22691  I_scope_neg

# %% [markdown]
# # Trying to implement Flaubert

# %% [markdown]
# # Load embeddings

# %%
if params['pretrainedEmbed']==True:
    ft_vec = load_vectors()

    ft_set = set(ft_vec.keys())
    cas_set = set(cas_neg['lem'].unique())

    inter_set = set(ft_set & cas_set)

    print("Fast text vocab: %d \nCAS vocab: %d \nIntersection vocab: %d"%(len(ft_set), len(cas_set), len(inter_set)))
elif params['pretrainedEmbed']=='fasttext':
    ft_vec = load_facebook_vectors('../embeddings/cc.fr.300.bin')
    # use ft_vec.wv['word'] to get vector values, works with long expressions too ("cancer du sein")
else:
    ft_vec = None

# %% [markdown]
# # Training

# %%
from multiprocessing import Pool
import gc

# BLOCK TO RELOAD PARAMS
import ruamel.yaml
with open('params.yml') as f:
    params = ruamel.yaml.load(f)
    
print(params)

if params['model_structure']['lib'] in ['torch', 'pytorch']:
    from train.train_torch import CV_train
else:
    from train.train import CV_train
    
with Pool(1):
    gc.collect()
    result_dict = CV_train(
        cas_neg,
        params,
        embeddings=ft_vec if params['pretrainedEmbed'] != 'flaubert' else None,
        flaubert_path="../Flaubert/xlm_bert_fra_base_lower" if params['pretrainedEmbed'] == 'flaubert' else None,
    )

    models = result_dict['models']
    model_function = result_dict['model_function']
    scores = result_dict['scores']
# Out:
# {'pretrainedEmbed': 'fasttext', 'label_level': 'sentence', 'neg_only': False, 'n_fold': 10, 'batch_size': 32, 'epochs': 100, 'hyper_params': {'lr': 0.001, 'lr_decay': 0, 'dropout': 0.3}, 'model_structure': {'with_attention': True, 'lib': 'torch', 'with_crf': False, 'word_embed': 300, 'pos_embed': None, 'cue_embed': None, 'lstm_size': 300}}
# /home/taille/.conda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:7: UnsafeLoaderWarning:
# The default 'Loader' for 'load(stream)' without further arguments can be unsafe.
# Use 'load(stream, Loader=ruamel.yaml.Loader)' explicitly if that is OK.
# Alternatively include the following in your code:
#
#   import warnings
#   warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# In most other cases you should consider using 'safe_load(stream)'
#   import sys
#         ############################
#         # Cross validaton split 0
#         ############################
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bd4f35fa517d> in <module>
#      20         params,
#      21         embeddings=ft_vec if params['pretrainedEmbed'] != 'flaubert' else None,
# ---> 22         flaubert_path="../Flaubert/xlm_bert_fra_base_lower" if params['pretrainedEmbed'] == 'flaubert' else None,
#      23     )
#      24
#
# ~/these/src/train/train_torch.py in CV_train(cas_neg, params, embeddings, train_size, flaubert_path)
#     134             model_function = BiLSTM
#     135         elif params['label_level']=='sentence':
# --> 136             from torch_model.Sent2Word import SentBiLSTM
#     137             model_function = SentBiLSTM
#     138
#
# ~/these/src/torch_model/Sent2Word.py in <module>
#      23 from importlib import reload
#      24
# ---> 25 import torch_model.Attention
#      26
#      27 reload(torch_model.Attention)
#
# ~/these/src/torch_model/Attention.py in <module>
#      41         return self.input_emb_size
#      42
# ---> 43 class BahdanauAttention(BaseAttention):
#      44     """This computes attention values based on
#      45     the original attention method proposed by
#
# ~/these/src/torch_model/Attention.py in BahdanauAttention()
#      76             setattr(self, f"attn_module_{ix}", attn_module)
#      77
# ---> 78     @overrides
#      79     def forward(self,
#      80                 context: torch.Tensor, # context is LSTM output
#
# NameError: name 'overrides' is not defined

# %%
score_df = format_results(scores, classes)

score_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-07fcfa7453af> in <module>
# ----> 1 score_df = format_results(scores, classes)
#       2
#       3 score_df
#
# NameError: name 'scores' is not defined

# %% [markdown]
# # Saving Experiment

# %%
es = ExpSaver(
    config=params,
    model=models[0],
    model_function=model_function,
    folder='../logs',
    results=score_df,
)

es.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45468d5e05d0> in <module>
# ----> 1 es = ExpSaver(
#       2     config=params,
#       3     model=models[0],
#       4     model_function=model_function,
#       5     folder='../logs',
#
# NameError: name 'ExpSaver' is not defined

# %% [markdown]
# # Get best results (may not be the best way to do so)

# %%
from train.results import get_best_results

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth', 57)

get_best_results(
    n_best=10,
    must_contain=['no_pos___no_cue'],
)
# Out:
# ../src/train/results.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[metric] = df[metric].astype(float)
# <style  type="text/css" >
#     #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow1_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow4_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow7_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow10_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow13_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow16_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow19_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col4 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col5 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col6 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col7 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow22_col8 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow25_col0 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow25_col1 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow25_col2 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_11ea_8416_002590fdddeerow25_col3 {
#             background-color:  #80c3e8;
#         }    #T_806586ca_4e57_
